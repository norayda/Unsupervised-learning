# %%
from utils import load_mnist, load_from_numpy
import numpy as np
import matplotlib.pyplot as plt
from kohonen import Kohonen

# %%
X, Y = load_mnist()
size_map = (20, 20)
K = size_map[0] * size_map[1]
gamma = 1
lr = 1e-2
epochs = 3000

model = Kohonen(X, size_map)
model.display_grid((28,28), float, True)
model.fit(epochs, lr, gamma)
model.display_grid((28,28), float, True)
# Out:
# 0
